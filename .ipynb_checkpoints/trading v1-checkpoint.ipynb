# %%
from binance import Client
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time
import schedule
import math
import scipy.stats as st
import ta
import statistics
import smtplib
import os
import time
from time import sleep
import re
import pandas as pd
import matplotlib.pyplot as plt
import pandas_ta as ta
import numpy as np
import datetime

api_key="pTZlrkaCbTEoa17nor24Tw53OWYFlMBQIOmaftSLcjg5lASfhZ0048zcxOZLrBgN"
api_secret="PxcyhPku5uQon1krBa3glze2sF7oZQ3gqb9GRVkh25OFvCtyAkML139l4z9d9BwG"
client=Client(api_key,api_secret)
client.get_account()
# Out:
# {'makerCommission': 10,
#  'takerCommission': 10,
#  'buyerCommission': 0,
#  'sellerCommission': 0,
#  'canTrade': True,
#  'canWithdraw': True,
#  'canDeposit': True,
#  'updateTime': 1655308182359,
#  'accountType': 'SPOT',
#  'balances': [{'asset': 'BTC', 'free': '0.00519000', 'locked': '0.00000000'},
#   {'asset': 'LTC', 'free': '0.44100000', 'locked': '0.00000000'},
#   {'asset': 'ETH', 'free': '0.03540000', 'locked': '0.00000000'},
#   {'asset': 'NEO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNB', 'free': '0.30267971', 'locked': '0.00000000'},
#   {'asset': 'QTUM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GAS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCC', 'free': '0.00000000', 'locked': '0.00000000'},
# ...

# %%
#Creating the list of all the cryptos that can be exchange with USDT
exchange_info = client.get_exchange_info()
cryptos=[]
for s in exchange_info['symbols']:
    sy=s['symbol']
    if re.search('..USDT',sy):
        cryptos.append(sy)
        
print(len(cryptos))
# Out:
# 405

# %%
def getdata(symbol, interval, lookback):
    frame=pd.DataFrame(client.get_historical_klines(symbol,interval,lookback))
    frame=frame.iloc[:,:6]
    frame.columns=['Time','Open','High','Low', 'Close','Volume']
    frame=frame.set_index('Time')
    frame.index=pd.to_datetime(frame.index,unit='ms')
    frame = frame.astype(float)
    frame['rsi']=ta.momentum.rsi(frame.Close, window=14)
    frame["EMA_20"] = ta.ema(frame.Close, length=20)
    frame['CRYPTO']=symbol
    frame['Date_time'] = frame.index
    return frame

#Checking the quantity of decimals to put in the qty of the order
def check_decimals(symbol):
    info = client.get_symbol_info(symbol)
    val = info['filters'][2]['stepSize']
    decimal = 0
    is_dec = False
    for c in val:
        if is_dec is True:
            decimal += 1
        if c == '1':
            break
        if c == '.':
            is_dec = True
    return decimal

# %% [markdown]
# # BREAKOUT STRATEGY:
# For this strategy we will use 4 indicators:
# 1. The pvt: this should go up by 3-4 standard deviations - 1 min chart
# 2. the Volumen Oscilator: Change in more than 4 std- 1 min chart (For this the std should be calculated based on past information)
# 3. The MACD for divergence to get the momentum of the crypto.
# 4. The price should break the 5 min bollinger bands.
#
# For this strategy we will see if in the last -10 min each of the cryptos has comply on at least 3 of them and buy if that is the case

# %% [markdown]
# ## Calculating the Oscilator
# 1. The oscilator consist on the difference between two Volumes EMA(fast=4 and slow=15)
# 2. Then this is compare with the standard deviation of the initial 4 hours of the data
# 3. Only the lines that comply with vol change >= 4 std are flag

# %%
df_1=getdata('FLMUSDT','1m','24 h ago UTC')
df_1['VEMASLOW_15']=ta.ema(df_1.Volume, length=15)
df_1['VEMAFAST_4']=ta.ema(df_1.Volume, length=4)
df_1['Vol_Osc']=df_1['VEMAFAST_4']-df_1['VEMASLOW_15']
df_1['Vol_change']=df_1['Vol_Osc'].diff(periods=1)
Vol_std=df_1['Volume'][:240].std()
print(Vol_std)
df_1['Vol_Flag']=np.where(df_1['Vol_change']>=4*Vol_std,"Yes","No")
#df_1_1=df_1.loc[df_1['Vol_Flag']=="Yes"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c2ffa5a55999> in <module>
# ----> 1 df_1=getdata('FLMUSDT','1m','24 h ago UTC')
#       2 df_1['VEMASLOW_15']=ta.ema(df_1.Volume, length=15)
#       3 df_1['VEMAFAST_4']=ta.ema(df_1.Volume, length=4)
#       4 df_1['Vol_Osc']=df_1['VEMAFAST_4']-df_1['VEMASLOW_15']
#       5 df_1['Vol_change']=df_1['Vol_Osc'].diff(periods=1)
#
# NameError: name 'getdata' is not defined

# %% [markdown]
# ## Calculating the MACD
# The MACD will be use for divergence, this means to calculate the momentum of the crypto and this should be greater than 3 times the standar deviation

# %%
macd_df=df_1.ta.macd(close='close', fast=4, slow=26, signal=15, append=True)
df_1['MACD']=macd_df[macd_df.columns[0]]
df_1['MACD_H']=macd_df[macd_df.columns[1]]
df_1['MACD_S']=macd_df[macd_df.columns[1]]
MACD_std=df_1['MACD_H'][:240].std()
print(MACD_std)
def macd_flag(df_1):
    if df_1['MACD_H']>3*MACD_std and df_1['MACD']>0:
        return "Yes"
    else:
        return "No"
df_1['MACD_Flag']=df_1.apply(macd_flag,axis=1)
df_1_1=df_1.loc[df_1['MACD_Flag']=="Yes"]
df_1_1.head(20)
# Out:
# 0.0007022353264089208
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, rsi, EMA_20, VEMASLOW_15, VEMAFAST_4, Vol_Osc, Vol_change, Vol_Flag, MACD_4_26_15, MACDh_4_26_15, MACDs_4_26_15, MACD, MACD_H, MACD_S, MACD_Flag]
# Index: []

# %% [markdown]
# ## Bollinger Bands
# The bollinger bands are use as confirmation of the big momentum so the price should overpass the upper limit. The bollinger bands are calculated as the mean + 2std. In this case we will verify if in any of the last 5 min close prices the bollinger band was crossed

# %%
df_5=getdata('FLMUSDT','5m','16 h ago UTC')
mean_5m=df_5['Close'].mean()
std_5m=df_5['Close'].std()
def boll(df_1):
    if df_1['Close']> mean_5m+ 2*std_5m:
        return "Yes"
    else:
        return "No"
df_1['boll_lim']=df_1.apply(boll,axis=1)
df_1_1=df_1.loc[df_1['boll_lim']=="Yes"]

# %%
breakouts=pd.DataFrame()
initial=datetime.datetime.now()
timeRun=0
while timeRun<30000:
    for cry in cryptos:
        final=datetime.datetime.now()
        timeRun=(final-initial).seconds
        qty=0
        df_f=pd.DataFrame()
        open_position=False
        try:
            df_1=getdata(cry,'1m','17 h ago UTC')
            df_1['VEMASLOW_30']=ta.ema(df_1.Volume, length=30)
            df_1['VEMAFAST_3']=ta.ema(df_1.Volume, length=3)
            df_1['Vol_Osc']=df_1['VEMAFAST_3']-df_1['VEMASLOW_30']
            Vol_std=df_1['Volume'][:240].std()
            df_1['Vol_Flag']=np.where(df_1['Vol_Osc']>=3*Vol_std,"Yes","No")

            macd_df=df_1.ta.macd(close='close', fast=4, slow=26, signal=15, append=True)
            df_1['MACD']=macd_df[macd_df.columns[0]]
            df_1['MACD_H']=macd_df[macd_df.columns[1]]
            df_1['MACD_S']=macd_df[macd_df.columns[1]]
            MACD_std=df_1['MACD_H'][:240].std()
            def macd_flag(df_1):
                if df_1['MACD_H']>2.5*MACD_std and df_1['MACD']>0:
                    return "Yes"
                else:
                    return "No"
            df_1['MACD_Flag']=df_1.apply(macd_flag,axis=1)

            df_5=getdata(cry,'5m','8 h ago UTC')
            mean_5m=df_5['Close'].mean()
            std_5m=df_5['Close'].std()
            def boll(df_1):
                if df_1['Close']> mean_5m+ 2*std_5m:
                    return "Yes"
                else:
                    return "No"
            df_1['boll_lim']=df_1.apply(boll,axis=1)

            def final_flag(df_1):
                if df_1['boll_lim']=="Yes" and df_1['MACD_Flag']=="Yes" and df_1['Vol_Flag']=="Yes" :
                    return "Yes"
                else:
                    return "No"
            df_1['final_flag']=df_1.apply(final_flag,axis=1)

            df_f=df_1[df_1['final_flag']=="Yes"]
        except:
            pass
        chandle3=df_1['Close'].iloc[-3]-df_1['Open'].iloc[-3]
        chandle3= 1 if chandle3 >0 else 0
        chandle2val=df_1['Close'].iloc[-2]-df_1['Open'].iloc[-2]
        chandle2= 1 if chandle2val >0 else 0
        chandle1val=df_1['Close'].iloc[-1]-df_1['Open'].iloc[-1]
        chandle1=1 if chandle1val >0 else 0
        final_val=df_1['final_flag'].iloc[-1]
        chandleRes= chandle1 + chandle3 +chandle2
        if final_val=="Yes" and chandleRes>=3:
            print('Buy Crypto ' + cry)
            price=df_1['Close'].iloc[-1]
            dec=check_decimals(cry)
            qty = round(20 / price, dec)
            order=client.create_order(symbol=cry, side='BUY', type='MARKET', quantity=qty)
            buyprice=float(order['fills'][0]['price'])
            print('Buy Crypto' + cry + str(buyprice))
            maxi=0.0
            startTime=datetime.datetime.now()
            sell=False
            open_position=True
            while open_position==True:
                time.sleep(1.5)
                dfsell= getdata(cry,'1m','10 m ago UTC')
                price=dfsell.Close.iloc[-1]
                gain=dfsell.Close.iloc[-1]-buyprice
                FinalTime=datetime.datetime.now()
                deltaTime=(FinalTime-startTime).seconds
                if price <= buyprice*0.99 and deltaTime<500:
                    print('Enter Sell rule1: ' + str(price) + "<="+ str(buyprice * 0.996))
                    order=client.create_order(symbol=cry,side='SELL', type= 'MARKET', quantity=qty)
                    try:
                        mycursor.execute("INSERT INTO crypto.excrecords (Date, Coin, Price, AmountUSD, AmountCry, TypeExc) VALUES(NOW(), %s, %s, %s , %s,'SELL_loss')",(cry,price,amountUS,qty))
                        mydb.commit()
                    except:
                        pass
                    break
                if price <= buyprice*0.999 and deltaTime>=500:
                    print('Enter Sell rule2: ' + str(price) + "<="+ str(buyprice * 0.992))
                    order=client.create_order(symbol=cry,side='SELL', type= 'MARKET', quantity=qty)
                    try:
                        mycursor.execute("INSERT INTO crypto.excrecords (Date, Coin, Price, AmountUSD, AmountCry, TypeExc) VALUES(NOW(), %s, %s, %s , %s,'SELL_loss')",(cry,price,amountUS,qty))
                        mydb.commit()
                    except:
                        pass
                    break

                else:   
                    if price>(buyprice*1.0015) or sell==True:
                        sell=True
                        if maxi<=gain:
                            maxi=gain
                            print("new max:" + str(maxi))
                        elif gain<= maxi*0.4 and sell==True and deltaTime<200 :
                            print('Enter Sell rule3: ' + str(gain) + "<="+ str(maxi * 0.992))
                            order=client.create_order(symbol=cry,side='SELL', type= 'MARKET', quantity=qty)
                            amountUS=round(price*qty,4)
                            price=round(price,4)
                            try:
                                mycursor.execute("INSERT INTO crypto.excrecords (Date, Coin, Price, AmountUSD, AmountCry, TypeExc) VALUES(NOW(), %s, %s, %s , %s,'SELL_win')",(cry,price,amountUS,qty))
                                mydb.commit()
                            except:
                                pass
                            break
                        elif gain<= maxi*0.8 and sell==True and deltaTime>200 and deltaTime<1600 :
                            print('Enter Sell rule4: ' + str(gain) + "<="+ str(maxi * 0.7))
                            order=client.create_order(symbol=cry,side='SELL', type= 'MARKET', quantity=qty)
                            amountUS=round(price*qty,4)
                            price=round(price,4)
                            try:
                                mycursor.execute("INSERT INTO crypto.excrecords (Date, Coin, Price, AmountUSD, AmountCry, TypeExc) VALUES(NOW(), %s, %s, %s , %s,'SELL_win')",(cry,price,amountUS,qty))
                                mydb.commit()
                            except:
                                pass
                            break

                        elif gain<= maxi*0.95 and sell==True and deltaTime>1600 :
                            print('Enter Sell rule5: ' + str(gain) + "<="+ str(maxi * 0.95))
                            order=client.create_order(symbol=cry,side='SELL', type= 'MARKET', quantity=qty)
                            amountUS=round(price*qty,4)
                            price=round(price,4)
                            try:
                                mycursor.execute("INSERT INTO crypto.excrecords (Date, Coin, Price, AmountUSD, AmountCry, TypeExc) VALUES(NOW(), %s, %s, %s , %s,'SELL_win')",(cry,price,amountUS,qty))
                                mydb.commit()
                            except:
                                pass
                            break
# Out:
# Buy Crypto ANTUSDT
# Buy CryptoANTUSDT2.098
# new max:0.006000000000000227
# new max:0.028999999999999915
# new max:0.06200000000000028
# new max:0.06499999999999995
# new max:0.09100000000000019
# new max:0.10899999999999999
# new max:0.13800000000000034
# new max:0.14500000000000002
# new max:0.15799999999999992
# new max:0.16700000000000026
# new max:0.18199999999999994
# new max:0.19799999999999995
# new max:0.2070000000000003
# new max:0.22199999999999998
# new max:0.2330000000000001
# new max:0.28200000000000003
# new max:0.28200000000000003
# new max:0.30100000000000016
# new max:0.31499999999999995
# Enter Sell rule3: 0.10000000000000009<=0.3124799999999999
# Buy Crypto XVSUSDT
# Buy CryptoXVSUSDT4.53
# new max:0.02999999999999936
# Enter Sell rule3: 0.0<=0.029759999999999367
# Buy Crypto AUTOUSDT
# Buy CryptoAUTOUSDT233.3
# new max:0.5999999999999943
# Enter Sell rule3: 0.0<=0.5951999999999944
# Buy Crypto ZRXUSDT
# Buy CryptoZRXUSDT0.3012
# new max:0.0008999999999999564
# ...

# %%
buyprice
# Out:
# 0.0

# %%
float(order['fills'][0]['price'])
# Out:
# 0.05031

# %%
order=client.create_order(symbol=cry,side='SELL', type= 'MARKET', quantity=qty)
# Out:
# ---------------------------------------------------------------------------
# BinanceAPIException                       Traceback (most recent call last)
# <ipython-input-28-450c7470ccf2> in <module>
# ----> 1 order=client.create_order(symbol=cry,side='SELL', type= 'MARKET', quantity=qty)
#
# ~\anaconda3\lib\site-packages\binance\client.py in create_order(self, **params)
#    1383
#    1384         """
# -> 1385         return self._post('order', True, data=params)
#    1386
#    1387     def order_limit(self, timeInForce=BaseClient.TIME_IN_FORCE_GTC, **params):
#
# ~\anaconda3\lib\site-packages\binance\client.py in _post(self, path, signed, version, **kwargs)
#     372
#     373     def _post(self, path, signed=False, version=BaseClient.PUBLIC_API_VERSION, **kwargs) -> Dict:
# --> 374         return self._request_api('post', path, signed, version, **kwargs)
#     375
#     376     def _put(self, path, signed=False, version=BaseClient.PUBLIC_API_VERSION, **kwargs) -> Dict:
#
# ...

# %%
df_1=getdata('ALPINEUSDT','1m','24 h ago UTC')
df_1['VEMASLOW_30']=ta.ema(df_1.Volume, length=30)
df_1['VEMAFAST_3']=ta.ema(df_1.Volume, length=3)
df_1['Vol_Osc']=df_1['VEMAFAST_3']-df_1['VEMASLOW_30']
Vol_std=df_1['Volume'][:240].std()
df_1['Vol_Flag']=np.where(df_1['Vol_Osc']>=3*Vol_std,"Yes","No")

macd_df=df_1.ta.macd(close='close', fast=4, slow=26, signal=15, append=True)
df_1['MACD']=macd_df[macd_df.columns[0]]
df_1['MACD_H']=macd_df[macd_df.columns[1]]
df_1['MACD_S']=macd_df[macd_df.columns[1]]
MACD_std=df_1['MACD_H'][:240].std()
def macd_flag(df_1):
    if df_1['MACD_H']>3*MACD_std and df_1['MACD']>0:
        return "Yes"
    else:
        return "No"
df_1['MACD_Flag']=df_1.apply(macd_flag,axis=1)

df_5=getdata('ALPINEUSDT','5m','16 h ago UTC')
mean_5m=df_5['Close'].mean()
std_5m=df_5['Close'].std()
def boll(df_1):
    if df_1['Close']> mean_5m+ 2*std_5m:
        return "Yes"
    else:
        return "No"
df_1['boll_lim']=df_1.apply(boll,axis=1)

def final_flag(df_1):
    if df_1['boll_lim']=="Yes" or df_1['MACD_Flag']=="Yes" or df_1['Vol_Flag']=="Yes" :
        return "Yes"
    else:
        return "No"
df_1['final_flag']=df_1.apply(final_flag,axis=1)
df_1_1=df_1[df_1['final_flag']=="Yes"]
df_1_1
# Out:
#                        Open    High     Low   Close    Volume        rsi  \
# Time
# 2022-06-14 19:20:00  2.3638  2.3880  2.3509  2.3879  13703.19  88.457869
# 2022-06-14 19:21:00  2.3879  2.5004  2.3834  2.4861  39504.23  94.751463
# 2022-06-14 19:22:00  2.4949  2.7006  2.4949  2.6612  48621.99  97.436062
# 2022-06-14 19:23:00  2.6808  2.7042  2.5893  2.6696  55374.81  97.502071
# 2022-06-14 19:24:00  2.6939  2.9000  2.6809  2.8603  95122.02  98.466992
# ...                     ...     ...     ...     ...       ...        ...
# 2022-06-15 01:44:00  2.6237  2.6463  2.6195  2.6195   5339.01  54.272891
# 2022-06-15 02:32:00  2.5769  2.5769  2.4694  2.5020  81104.26  24.924873
# 2022-06-15 02:33:00  2.4993  2.5069  2.4945  2.5034   6546.47  25.529104
# 2022-06-15 02:34:00  2.4976  2.5043  2.4912  2.4982   4308.51  24.732869
# 2022-06-15 02:35:00  2.4981  2.4981  2.4639  2.4834   8095.42  22.574768
#
#                        EMA_20      CRYPTO           Date_time   VEMASLOW_30  \
# Time
# ...

# %%
dfsell= getdata('JSTUSDT','1m','10 m ago UTC')
price=dfsell.Close.iloc[-1]
p=str(price)
p[::-1].find('.')
# Out:
# 5
